# %% [markdown]
# # NiTi Lab
#
# Here I am going to show you how to identify the True transition temperature for a NiTi sample.
#
# We are going to start by loading in some data.  We can use Pandas to load in the csv file

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
hyst = pd.read_csv("DSCHysterisis MSE361Spring 2022Hysterisis Measurements Total.csv")

# %%
hyst
# Out:
#     Ramp Rate(°C/min)  T1(°C)  T2(°C) T1(°C).1 T2(°C).1  T1(°C).2 T2(°C).2
# 0                  20   51.98   43.72    51.98    43.72     51.98    43.72
# 1                  19   51.74   44.46      NaN      NaN     53.02    44.81
# 2                  18   66.60   31.44      NaN      NaN     52.07    44.92
# 3                  17   53.65   46.83      NaN      NaN       NaN      NaN
# 4                  16   54.04   47.25    46.42    37.71       NaN      NaN
# 5                  15   51.94   44.50    52.15    44.49     51.79    44.36
# 6                  14   51.82   45.56    51.94    44.94       NaN      NaN
# 7                  13   51.95   44.30    67.84    26.48     51.85    45.02
# 8                  12     NaN     NaN      NaN      NaN     51.28    44.96
# 9                  11   51.63   47.44    51.38    45.72       NaN      NaN
# 10                 10     NaN     NaN    50.69    45.92       NaN      NaN
# ...

# %%
ax,figplt.subplots(1, )
plt.scatter(hyst["Ramp Rate(°C/min)"],hyst["T1(°C)"])
plt.scatter(hyst["Ramp Rate(°C/min)"],hyst["T2(°C)"])
